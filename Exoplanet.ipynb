# %% [markdown]
# <a href="https://colab.research.google.com/github/PSamita/Exoplanets/blob/main/Exoplanet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create a dataframe planet1
p1 = {'Spectral Type': ['G'], 'Age of the System (Gyr)': [8.16], 'Binary System': ['Single Star'], 'Stellar Luminosities (Solar Units)': [1.32], 'Total Stellar Mass (Solar Masses)': [1.07], 'Stellar Radius (Solar Radii)': [1.07], 'Planet Orbital Period (Years)': [1.73], 'Planet Semi-Major Axis (AU)': [1.47], 'Planet Mass (Earth Masses)':[3.16], 'Planet Radius (Earth Radii)': [1.41], 'Eccentricity': [0.0954], 'N2': [84.376], 'CO2':[2.721], 'H2O': [0.511], 'O2': [12.393], 'Others':[0.000], 
      'Number of other (known) Planets in the System': [3], 'Location in the Galaxy': ['Disk'], 'Distance from Earth (lightyears)': [63.9], 'Atmospheric Pressure (atm)': [1.65], 'Planetary Albedo':[0.374], 'Planet Axial Tilt (degrees)': [21.2], 'Planet Rotation Period (Hours)': [20.2], 'Magnetic Field Strength (Units of Earth Magnetic Field)': [0.000663]}

planet1 = pd.DataFrame(data=p1)

planet1
# Out:
#   Spectral Type  Age of the System (Gyr) Binary System  \
# 0             G                     8.16   Single Star
#
#    Stellar Luminosities (Solar Units)  Total Stellar Mass (Solar Masses)  \
# 0                                1.32                               1.07
#
#    Stellar Radius (Solar Radii)  Planet Orbital Period (Years)  \
# 0                          1.07                           1.73
#
#    Planet Semi-Major Axis (AU)  Planet Mass (Earth Masses)  \
# 0                         1.47                        3.16
#
#    Planet Radius (Earth Radii)  ...      O2  Others  \
# 0                         1.41  ...  12.393     0.0
#
#    Number of other (known) Planets in the System  Location in the Galaxy  \
# 0                                              3                    Disk
#
#    Distance from Earth (lightyears)  Atmospheric Pressure (atm)  \
# 0                              63.9                        1.65
#
#    Planetary Albedo Planet Axial Tilt (degrees)  \
# 0             0.374                        21.2
#
#    Planet Rotation Period (Hours)  \
# 0                            20.2
#
#    Magnetic Field Strength (Units of Earth Magnetic Field)
# 0                                           0.000663
#
# [1 rows x 24 columns]

# %%
# Create a dataframe planet2
p2 = {'Spectral Type': ['F'], 'Age of the System (Gyr)': [0.0568], 'Binary System': ['Single Star'], 'Stellar Luminosities (Solar Units)': [4.49], 'Total Stellar Mass (Solar Masses)': [1.46], 'Stellar Radius (Solar Radii)': [1.43], 'Planet Orbital Period (Years)': [4.81], 'Planet Semi-Major Axis (AU)': [3.23], 'Planet Mass (Earth Masses)':[3.07], 'Planet Radius (Earth Radii)': [1.47], 'Eccentricity': [0.11], 'N2': [88.003], 'CO2':[1.897], 'H2O': [4.838], 'O2': [5.261], 'Others':[0.000], 
      'Number of other (known) Planets in the System': [3], 'Location in the Galaxy': ['Open Cluster'], 'Distance from Earth (lightyears)': [1.58E+03], 'Atmospheric Pressure (atm)': [0.93], 'Magnetic Field Strength (Units of Earth Magnetic Field)': [1.2]}

planet2 = pd.DataFrame(data=p2)

planet2
# Out:
#   Spectral Type  Age of the System (Gyr) Binary System  \
# 0             F                   0.0568   Single Star
#
#    Stellar Luminosities (Solar Units)  Total Stellar Mass (Solar Masses)  \
# 0                                4.49                               1.46
#
#    Stellar Radius (Solar Radii)  Planet Orbital Period (Years)  \
# 0                          1.43                           4.81
#
#    Planet Semi-Major Axis (AU)  Planet Mass (Earth Masses)  \
# 0                         3.23                        3.07
#
#    Planet Radius (Earth Radii)  ...      N2    CO2    H2O     O2  Others  \
# 0                         1.47  ...  88.003  1.897  4.838  5.261     0.0
#
#    Number of other (known) Planets in the System  Location in the Galaxy  \
# 0                                              3            Open Cluster
#
#   Distance from Earth (lightyears)  Atmospheric Pressure (atm)  \
# 0                           1580.0                        0.93
#
#    Magnetic Field Strength (Units of Earth Magnetic Field)
# 0                                                1.2
#
# [1 rows x 21 columns]

# %%
# Create a dataframe planet3
p3 = {'Spectral Type': ['K', 'M'], 'Age of the System (Gyr)': [1.01, 1.01], 'Binary System': ['Close Binary', 'Close Binary'], 'Stellar Luminosities (Solar Units)': [0.451, 0.0135], 'Total Stellar Mass (Solar Masses)': [1.11, 1.11], 'Stellar Radius (Solar Radii)': [0.828, 0.312], 'Planet Orbital Period (Years)': [0.341, 0.341], 'Planet Semi-Major Axis (AU)': [0.505, 0.505], 'Planet Mass (Earth Masses)':[1.28, 1.28], 'Planet Radius (Earth Radii)': [1.13, 1.13], 'Eccentricity': [0.141, 0.141], 'CO2':[64.316, 64.316], 'H2O': [3.875, 3.875], 'O2': [31.809, 31.809], 'Others':[0.000, 0.000], 
      'Number of other (known) Planets in the System': [0, 0], 'Location in the Galaxy': ['Disk', 'Disk'], 'Distance from Earth (lightyears)': [30.5, 30.5], 'Planet Axial Tilt (degrees)': [28, 28], 'Planet Rotation Period (Hours)': [23.7, 23.7], 'Magnetic Field Strength (Units of Earth Magnetic Field)': [0.938, 0.938]}

planet3 = pd.DataFrame(data=p3)

planet3
# Out:
#   Spectral Type  Age of the System (Gyr) Binary System  \
# 0             K                     1.01  Close Binary
# 1             M                     1.01  Close Binary
#
#    Stellar Luminosities (Solar Units)  Total Stellar Mass (Solar Masses)  \
# 0                              0.4510                               1.11
# 1                              0.0135                               1.11
#
#    Stellar Radius (Solar Radii)  Planet Orbital Period (Years)  \
# 0                         0.828                          0.341
# 1                         0.312                          0.341
#
#    Planet Semi-Major Axis (AU)  Planet Mass (Earth Masses)  \
# 0                        0.505                        1.28
# 1                        0.505                        1.28
#
#    Planet Radius (Earth Radii)  ...     CO2    H2O      O2  Others  \
# 0                         1.13  ...  64.316  3.875  31.809     0.0
# 1                         1.13  ...  64.316  3.875  31.809     0.0
#
#    Number of other (known) Planets in the System  Location in the Galaxy  \
# 0                                              0                    Disk
# 1                                              0                    Disk
#
#   Distance from Earth (lightyears)  Planet Axial Tilt (degrees)  \
# 0                             30.5                           28
# 1                             30.5                           28
#
#    Planet Rotation Period (Hours)  \
# 0                            23.7
# 1                            23.7
#
#    Magnetic Field Strength (Units of Earth Magnetic Field)
# 0                                              0.938
# 1                                              0.938
#
# [2 rows x 21 columns]

# %% [markdown]
# Observations:
